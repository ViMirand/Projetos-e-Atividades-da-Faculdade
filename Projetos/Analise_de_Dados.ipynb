# %% [markdown]
# > Dados Abertos - MEC

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/MyDrive/Datasets/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_ies = pd.read_csv(path + 'PDA_Lista_Instituicoes_Ensino_Superior_do_Brasil_EMEC.csv', sep=',')
df_graduacoes = pd.read_csv(path + 'PDA_Dados_Cursos_Graduacao_Brasil.csv', sep=',')

# %% [markdown]
# > INSTITUIÇÕES DE ENSINO SUPERIOR

# %%
df_ies
# Out:
#       CODIGO_DA_IES                                        NOME_DA_IES  \
# 0             21995             Faculdade de Tecnologia Senac Curitiba
# 1              1768                         FACULDADE REGIONAL SERRANA
# 2             23261       Faculdade São Judas de São Bernardo do Campo
# 3             14123  Faculdade Presidente Antônio Carlos de Bom Suc...
# 4             17952                 Faculdade de Tecnologia de Jacareí
# ...             ...                                                ...
# 4603           1195          FACULDADE SENAI DE TECNOLOGIA MECATRÔNICA
# 4604            925        FACULDADE DE CIÊNCIAS GERÊNCIAIS DE VILHENA
# 4605          22739                        Instituto SOCIESC de Itajaí
# 4606          24025         Centro de Ensino Superior de Serra Dourada
# 4607           5290  FACULDADE ANHANGUERA DE CIÊNCIAS E TECNOLOGIA ...
#
#                    SIGLA CATEGORIA_DA_IES COMUNITARIA CONFESSIONAL  \
# ...

# %%
df_ies.tail()
# Out:
#       CODIGO_DA_IES                                        NOME_DA_IES  \
# 4603           1195          FACULDADE SENAI DE TECNOLOGIA MECATRÔNICA
# 4604            925        FACULDADE DE CIÊNCIAS GERÊNCIAIS DE VILHENA
# 4605          22739                        Instituto SOCIESC de Itajaí
# 4606          24025         Centro de Ensino Superior de Serra Dourada
# 4607           5290  FACULDADE ANHANGUERA DE CIÊNCIAS E TECNOLOGIA ...
#
#         SIGLA CATEGORIA_DA_IES COMUNITARIA CONFESSIONAL FILANTROPICA  \
# 4603    SENAI          Privada           N            N            X
# 4604     FCGV          Privada           N            N            X
# 4605  SOCIESC          Privada           N            N            X
# 4606      NaN          Privada           N            N            X
# 4607      NaN          Privada           N            N            X
#
#      ORGANIZACAO_ACADEMICA  CODIGO_MUNICIPIO_IBGE MUNICIPIO   UF SITUACAO_IES
# ...

# %%
df_ies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4608 entries, 0 to 4607
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CODIGO_DA_IES          4608 non-null   int64
#  1   NOME_DA_IES            4608 non-null   object
#  2   SIGLA                  3745 non-null   object
#  3   CATEGORIA_DA_IES       4608 non-null   object
#  4   COMUNITARIA            4608 non-null   object
#  5   CONFESSIONAL           4608 non-null   object
#  6   FILANTROPICA           4608 non-null   object
#  7   ORGANIZACAO_ACADEMICA  4608 non-null   object
#  8   CODIGO_MUNICIPIO_IBGE  4059 non-null   float64
#  9   MUNICIPIO              4059 non-null   object
#  10  UF                     4059 non-null   object
#  11  SITUACAO_IES           4608 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 432.1+ KB

# %%
org_academicas = df_ies['ORGANIZACAO_ACADEMICA'].unique()

# %%
sorted(org_academicas)
# Out:
# ['Centro Federal de Educação Tecnológica',
#  'Centro Universitário',
#  'Escola de Governo',
#  'Faculdade',
#  'Faculdade de Tecnologia',
#  'Faculdades Integradas',
#  'Instituição Especialmente Credenciada para oferta de cursos lato sensu',
#  'Instituto Federal de Educação, Ciência e Tecnologia',
#  'Instituto Superior ou Escola Superior',
#  'Universidade']

# %%
municipio = df_ies['MUNICIPIO'].unique()

# %%
sorted(municipio, key=str)
# Out:
# ['Abadia dos Dourados',
#  'Abaetetuba',
#  'Abaeté',
#  'Adamantina',
#  'Afogados da Ingazeira',
#  'Afonso Cláudio',
#  'Aguaí',
#  'Agudos',
#  'Aimorés',
#  'Alagoinhas',
#  'Alegre',
#  'Alfenas',
#  'Almenara',
#  'Alta Floresta',
#  'Altamira',
#  'Alto Boa Vista',
#  'Alto Horizonte',
#  'Alto Santo',
#  'Alvarenga',
#  'Alvorada',
#  'Além Paraíba',
#  'Amambaí',
#  'Amargosa',
#  'Americana',
#  'Amparo',
#  'Ampére',
#  'Ananindeua',
#  'Anchieta',
#  'Andradina',
#  'Andrelândia',
#  'Anicuns',
#  'Anápolis',
#  'Aparecida de Goiânia',
#  'Apodi',
#  'Apucarana',
#  'Aquidauana',
#  'Aracaju',
#  'Aracati',
#  'Aracruz',
#  'Araguapaz',
#  'Araguari',
#  'Araguatins',
#  'Araguaína',
#  'Arapiraca',
#  'Arapongas',
#  'Arapoti',
#  'Araputanga',
#  'Araranguá',
#  'Araraquara',
#  'Araras',
#  'Araripina',
#  'Araruama',
#  'Araucária',
#  'Araxá',
#  'Araçatuba',
#  'Araçuaí',
#  'Arcos',
#  'Arcoverde',
#  'Ariquemes',
#  'Artur Nogueira',
#  'Arujá',
#  'Assis',
# ...

# %%
df_ies['CATEGORIA_DA_IES'].unique()
# Out:
# array(['Privada', 'Pública'], dtype=object)

# %%
df_ies['CATEGORIA_DA_IES'].value_counts()
# Out:
# CATEGORIA_DA_IES
# Privada    4082
# Pública     526
# Name: count, dtype: int64

# %%
df_ies['CATEGORIA_DA_IES'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='CATEGORIA_DA_IES'>

# %%
df_ies['UF'].value_counts()
# Out:
# UF
# SP    935
# MG    551
# PR    276
# BA    217
# RJ    206
# GO    185
# PE    178
# RS    169
# SC    168
# CE    141
# DF    138
# ES    130
# MT     99
# PA     98
# MA     85
# MS     66
# PI     65
# PB     62
# TO     46
# AM     44
# RN     44
# AL     43
# RO     42
# SE     27
# AP     18
# AC     13
# RR     13
# Name: count, dtype: int64

# %%
df_ies['UF'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='UF'>

# %%
df_ies.groupby('UF')['CATEGORIA_DA_IES'].value_counts()
# Out:
# UF  CATEGORIA_DA_IES
# AC  Privada              11
#     Pública               2
# AL  Privada              39
#     Pública               4
# AM  Privada              41
#     Pública               3
# AP  Privada              15
#     Pública               3
# BA  Privada             207
#     Pública              10
# CE  Privada             134
#     Pública               7
# DF  Privada             118
#     Pública              20
# ES  Privada             123
#     Pública               7
# GO  Privada             168
#     Pública              17
# MA  Privada              80
#     Pública               5
# MG  Privada             523
#     Pública              28
# MS  Privada              62
#     Pública               4
# MT  Privada              94
#     Pública               5
# PA  Privada              91
#     Pública               7
# PB  Privada              58
#     Pública               4
# PE  Privada             145
#     Pública              33
# ...

# %%
df_ies.groupby(['UF', 'CATEGORIA_DA_IES']).size().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='UF'>

# %%
# FACULDADES DE MANAUS

# %%
df_ies[df_ies['MUNICIPIO'] == 'Manaus']
# Out:
#       CODIGO_DA_IES                                        NOME_DA_IES  \
# 70             3397  FACULDADE BOAS NOVAS DE CIÊNCIAS TEOLÓGICAS, S...
# 247           17744                        Faculdade Estácio de Manaus
# 277            1638                              FACULDADE DO AMAZONAS
# 782           23984                              Faculdade do Amazonas
# 1144           1436                         CENTRO UNIVERSITÁRIO ESBAM
# 1189           3172                 UNIVERSIDADE DO ESTADO DO AMAZONAS
# 1265           2147               Centro Universitário CEUNI - FAMETRO
# 1316          25522                               FACULDADE UNITBRASIL
# 1373          28544              FACULDADE DESEMBARGADOR PAULO FEITOZA
# 1393            668  CENTRO UNIVERSITÁRIO DE ENSINO SUPERIOR DO AMA...
# 1536           1049                INSTITUTO DE ENSINO SUPERIOR FUCAPI
# 1587           1812  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...
# ...

# %%
df_manaus = df_ies[df_ies['MUNICIPIO'] == 'Manaus']

# %%
len(df_manaus)
# Out:
# 35

# %%
df_manaus['CATEGORIA_DA_IES'].value_counts()
# Out:
# CATEGORIA_DA_IES
# Privada    32
# Pública     3
# Name: count, dtype: int64

# %%
df_manaus['CATEGORIA_DA_IES'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='CATEGORIA_DA_IES'>

# %%
publicas = df_ies[df_ies['CATEGORIA_DA_IES'] == 'Pública']

# %%
publicas
# Out:
#       CODIGO_DA_IES                                        NOME_DA_IES  \
# 4             17952                 Faculdade de Tecnologia de Jacareí
# 11            25613        ACADEMIA DE POLÍCIA MILITAR DE MINAS GERAIS
# 12            14724  INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNO...
# 14            18099    Faculdade de Tecnologia de Diadema Luigi Papaiz
# 35             4070              ESCOLA AGROTÉCNICA FEDERAL DE SALINAS
# ...             ...                                                ...
# 4574          30381                   Escola de Governo de Mato Grosso
# 4593           3486        INSTITUTO SUPERIOR DE EDUCAÇÃO DE ITUIUTABA
# 4595          30858  FACULDADE DE TECNOLOGIA DE RIO CLARO (FATEC RI...
# 4596           3480      FACULDADE DE CIÊNCIAS JURÍDICAS DE DIAMANTINA
# 4597          29329  ESCOLA SUPERIOR DA MAGISTRATURA DO ESTADO DE M...
#
#               SIGLA CATEGORIA_DA_IES COMUNITARIA CONFESSIONAL FILANTROPICA  \
# ...

# %%
PUBLICAS_ATIVAS = publicas[publicas['SITUACAO_IES'] == 'ATIVA']

# %%
PUBLICAS_ATIVAS['UF'].value_counts()
# Out:
# UF
# SP    117
# RJ     41
# PE     33
# MG     28
# PR     21
# DF     20
# GO     17
# SC     12
# BA     10
# RS     10
# ES      7
# CE      7
# PA      7
# TO      6
# RN      6
# PI      5
# MA      5
# MT      5
# AL      4
# PB      4
# MS      4
# AP      3
# RR      3
# AM      3
# AC      2
# SE      2
# RO      2
# Name: count, dtype: int64

# %%
PUBLICAS_ATIVAS[PUBLICAS_ATIVAS['UF']=='SP']
# Out:
#       CODIGO_DA_IES                                        NOME_DA_IES  \
# 4             17952                 Faculdade de Tecnologia de Jacareí
# 14            18099    Faculdade de Tecnologia de Diadema Luigi Papaiz
# 38               34               FACULDADE DE TECNOLOGIA DE SÃO PAULO
# 40             4024                  FACULDADE DE TECNOLOGIA DE MOCOCA
# 52            15709  Faculdade de Tecnologia de Osasco - Prefeito H...
# ...             ...                                                ...
# 3880            602               INSTITUTO TECNOLÓGICO DE AERONÁUTICA
# 3893          15576         Faculdade de Tecnologia de Mogi das Cruzes
# 3904          18817               Faculdade de Tecnologia de São Roque
# 3959           4926            FACULDADE DE TECNOLOGIA DE PRAIA GRANDE
# 4023           1583              FACULDADE DE TECNOLOGIA DE INDAIATUBA
#
#               SIGLA CATEGORIA_DA_IES COMUNITARIA CONFESSIONAL FILANTROPICA  \
# ...

# %% [markdown]
# > Graduações

# %%
df_graduacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 902676 entries, 0 to 902675
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   CODIGO_IES                902676 non-null  int64
#  1   NOME_IES                  902676 non-null  object
#  2   CATEGORIA_ADMINISTRATIVA  902676 non-null  object
#  3   ORGANIZACAO_ACADEMICA     902676 non-null  object
#  4   CODIGO_CURSO              902676 non-null  int64
#  5   NOME_CURSO                902676 non-null  object
#  6   GRAU                      902676 non-null  object
#  7   AREA_OCDE                 680577 non-null  object
#  8   MODALIDADE                902676 non-null  object
#  9   SITUACAO_CURSO            902676 non-null  object
#  10  QT_VAGAS_AUTORIZADAS      902676 non-null  int64
#  11  CARGA_HORARIA             902676 non-null  int64
#  12  CODIGO_AREA_OCDE_CINE     902649 non-null  object
# ...

# %%
df_graduacoes
# Out:
#         CODIGO_IES                                  NOME_IES  \
# 0             4751           CENTRO UNIVERSITÁRIO UNIFATECIE
# 1             1491        CENTRO UNIVERSITÁRIO INTERNACIONAL
# 2             1472    CENTRO UNIVERSITÁRIO LEONARDO DA VINCI
# 3              221              UNIVERSIDADE CRUZEIRO DO SUL
# 4             1472    CENTRO UNIVERSITÁRIO LEONARDO DA VINCI
# ...            ...                                       ...
# 902671         163                UNIVERSIDADE ESTÁCIO DE SÁ
# 902672        1491        CENTRO UNIVERSITÁRIO INTERNACIONAL
# 902673        1491        CENTRO UNIVERSITÁRIO INTERNACIONAL
# 902674         298  Universidade Pitágoras Unopar Anhanguera
# 902675        3840              CENTRO UNIVERSITÁRIO FACVEST
#
#            CATEGORIA_ADMINISTRATIVA ORGANIZACAO_ACADEMICA  CODIGO_CURSO  \
# 0       Privada com fins lucrativos  Centro Universitário       1556773
# 1       Privada com fins lucrativos  Centro Universitário       1186955
# ...

# %%
sorted(df_graduacoes['NOME_CURSO'].unique())
# Out:
# ['ABI - ANTROPOLOGIA',
#  'ABI - ARTES CÊNICAS',
#  'ABI - ARTES PLÁSTICAS',
#  'ABI - ARTES VISUAIS',
#  'ABI - CICLO BÁSICO COMPOSIÇÃO/REGÊNCIA',
#  'ABI - CICLO BÁSICO MATERIAIS/METALÚRGICA/NUCLEAR',
#  'ABI - CIÊNCIA DA COMPUTAÇÃO',
#  'ABI - CIÊNCIAS ATUARIAIS E ESTATÍSTICA',
#  'ABI - CIÊNCIAS BIOLÓGICAS',
#  'ABI - CIÊNCIAS BIOMÉDICAS',
#  'ABI - CIÊNCIAS DA ATIVIDADE FÍSICA',
#  'ABI - CIÊNCIAS DA NATUREZA',
#  'ABI - CIÊNCIAS DA NATUREZA: CIÊNCIAS E BIOLOGIA, CIÊNCIAS E FÍSICA OU CIÊNCIAS E QUÍMICA',
#  'ABI - CIÊNCIAS DA TERRA',
#  'ABI - CIÊNCIAS EXATAS',
#  'ABI - CIÊNCIAS SOCIAIS',
#  'ABI - CIêNCIAS SOCIAIS',
#  'ABI - COMPOSIÇÃO E REGÊNCIA',
#  'ABI - COMUNICAÇÃO SOCIAL',
#  'ABI - CONSTRUÇÃO CIVIL',
#  'ABI - DANÇA',
#  'ABI - DESIGN',
#  'ABI - ECONOMIA EMPRESARIAL E CONTROLADORIA',
#  'ABI - EDUCAÇÃO FÍSICA',
#  'ABI - EDUCAÇÃO FÍSICA - LICENCIATURA OU BACHARELADO',
#  'ABI - EDUCAÇÃO FÍSICA E ESPORTE',
#  'ABI - EDUCAÇÃO INTERCULTURAL',
#  'ABI - ENFERMAGEM',
# ...

# %%
df_graduacoes['NOME_CURSO'].value_counts()
# Out:
# NOME_CURSO
# ADMINISTRAÇÃO                                                                                        22997
# PEDAGOGIA                                                                                            22587
# EDUCAÇÃO FÍSICA                                                                                      18852
# CIÊNCIAS CONTÁBEIS                                                                                   17545
# GESTÃO DE RECURSOS HUMANOS                                                                           16328
#                                                                                                      ...
# MÚSICA POPULAR - PRODUÇÃO MUSICAL                                                                        1
# CENOGRAFIA E INDUMENTÁRIA                                                                                1
# RECURSOS DE QUÍMICA AMBIENTAL                                                                            1
# ...

# %%
computacao = df_graduacoes[df_graduacoes['NOME_CURSO'] == 'CIÊNCIAS DA COMPUTAÇÃO']

# %%
computacao
# Out:
#         CODIGO_IES                                        NOME_IES  \
# 1155           163                      UNIVERSIDADE ESTÁCIO DE SÁ
# 1978           322                           UNIVERSIDADE PAULISTA
# 2066           322                           UNIVERSIDADE PAULISTA
# 2279           322                           UNIVERSIDADE PAULISTA
# 2335           322                           UNIVERSIDADE PAULISTA
# ...            ...                                             ...
# 899922        2123                 CENTRO UNIVERSITÁRIO MAX PLANCK
# 900223        1270  CENTRO UNIVERSITÁRIO ESTÁCIO DE RIBEIRÃO PRETO
# 900342        1270  CENTRO UNIVERSITÁRIO ESTÁCIO DE RIBEIRÃO PRETO
# 900925         163                      UNIVERSIDADE ESTÁCIO DE SÁ
# 901050        1978                    Centro Universitário Fametro
#
#            CATEGORIA_ADMINISTRATIVA ORGANIZACAO_ACADEMICA  CODIGO_CURSO  \
# 1155    Privada com fins lucrativos          Universidade       1443998
# ...

# %%
COUNT = computacao[computacao['MODALIDADE']=='Educação a Distância']

# %%
COUNT.groupby('REGIAO')['MODALIDADE'].value_counts()
# Out:
# REGIAO             MODALIDADE
# CENTRO-OESTE       Educação a Distância    172
# IGNORADO/EXTERIOR  Educação a Distância      1
# NORDESTE           Educação a Distância    326
# NORTE              Educação a Distância    164
# SUDESTE            Educação a Distância    666
# SUL                Educação a Distância    172
# Name: count, dtype: int64

# %%
COUNT.groupby('REGIAO')['MODALIDADE'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
computacao['REGIAO'].value_counts()
# Out:
# REGIAO
# SUDESTE              691
# NORDESTE             338
# SUL                  182
# CENTRO-OESTE         176
# NORTE                168
# IGNORADO/EXTERIOR      1
# Name: count, dtype: int64

# %%
computacao['REGIAO'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='REGIAO'>
